# %%
# Starter code
from pyspark.sql import SparkSession

# Create spark session
spark = SparkSession \
    .builder \
    .appName("Sparkify") \
    .getOrCreate()

# Read in full sparkify dataset
event_data = "s3n://dsnd-sparkify/sparkify_event_data.json"
df = spark.read.json(event_data)
df.head()
# Out:
# VBox()
# Row(artist=u'Popol Vuh', auth=u'Logged In', firstName=u'Shlok', gender=u'M', itemInSession=278, lastName=u'Johnson', length=524.32934, level=u'paid', location=u'Dallas-Fort Worth-Arlington, TX', method=u'PUT', page=u'NextSong', registration=1533734541000, sessionId=22683, song=u'Ich mache einen Spiegel - Dream Part 4', status=200, ts=1538352001000, userAgent=u'"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId=u'1749042')

# %% [markdown]
# ### Import Libraries

# %%
# import libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg, col, concat, desc, explode, lit, min, max, split, udf, count, when, isnull, collect_list
from pyspark.sql.types import IntegerType, BooleanType, FloatType
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.storagelevel import StorageLevel
from pyspark.ml.classification import LogisticRegression, GBTClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
# Out:
# VBox()

# %%
print((df.count(), len(df.columns)))
# Out:
# VBox()
# (26259199, 18)

# %%
df.columns
# Out:
# VBox()
# ['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName', 'length', 'level', 'location', 'method', 'page', 'registration', 'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId']

# %%
df.select('page').distinct().show(50)
# Out:
# VBox()
# +--------------------+
# |                page|
# +--------------------+
# |              Cancel|
# |    Submit Downgrade|
# |         Thumbs Down|
# |                Home|
# |           Downgrade|
# |         Roll Advert|
# |              Logout|
# |       Save Settings|
# |Cancellation Conf...|
# |               About|
# | Submit Registration|
# |            Settings|
# |               Login|
# |            Register|
# |     Add to Playlist|
# |          Add Friend|
# |            NextSong|
# |           Thumbs Up|
# |                Help|
# |             Upgrade|
# |               Error|
# |      Submit Upgrade|
# +--------------------+

# %% [markdown]
# ### Get rid of unecessary columns and add label for churned users

# %%
df_clean = df.select('artist','auth','firstName','gender','lastName','length','level','location','page','song','ts','userId')
# Out:
# VBox()

# %%
df_churn = df_clean.groupby('userId').agg(collect_list('auth').alias("auths"))
# Out:
# VBox()

# %%
churned = udf(lambda x: 'Cancelled' in x)
# Out:
# VBox()

# %%
df_churn = df_churn.withColumn("Churned", churned(df_churn.auths))
df_churn = df_churn.drop('auths')
# Out:
# VBox()

# %%
df_label = df_churn.join(df_clean,'userId')
# Out:
# VBox()

# %%
df_label.show()
# Out:
# VBox()
# +-------+-------+--------------------+---------+---------+------+--------+---------+-----+-----------+-------------+--------------------+-------------+
# | userId|Churned|              artist|     auth|firstName|gender|lastName|   length|level|   location|         page|                song|           ts|
# +-------+-------+--------------------+---------+---------+------+--------+---------+-----+-----------+-------------+--------------------+-------------+
# |1000280|   true|            Coldplay|Logged In|    Frank|     M|  Warren|307.51302| free|Findlay, OH|     NextSong|              Clocks|1538428238000|
# |1000280|   true|  Charttraxx Karaoke|Logged In|    Frank|     M|  Warren|225.17506| free|Findlay, OH|     NextSong|           Fireflies|1538428545000|
# |1000280|   true|        Dixie Chicks|Logged In|    Frank|     M|  Warren|351.84281| free|Findlay, OH|     NextSong|             Lullaby|1538428770000|
# |1000280|   true|             Erasure|Logged In|    Frank|     M|  Warren|242.28526| free|Findlay, OH|     NextSong|    Always (7'' Mix)|1538429121000|
# |1000280|   true|      Britney Spears|Logged In|    Frank|     M|  Warren|210.15465| free|Findlay, OH|     NextSong|...Baby One More ...|1538429363000|
# |1000280|   true|             Phoenix|Logged In|    Frank|     M|  Warren|198.03383| free|Findlay, OH|     NextSong|           Too Young|1538429573000|
# |1000280|   true|                null|Logged In|    Frank|     M|  Warren|     null| free|Findlay, OH|  Thumbs Down|                null|1538429574000|
# |1000280|   true|            Al Green|Logged In|    Frank|     M|  Warren|133.58975| free|Findlay, OH|     NextSong|I Say A Little Pr...|1538429771000|
# |1000280|   true|   Brotha Lynch Hung|Logged In|    Frank|     M|  Warren| 67.91791| free|Findlay, OH|     NextSong|              Q-Ball|1538429904000|
# |1000280|   true|    Five Iron Frenzy|Logged In|    Frank|     M|  Warren|236.09424| free|Findlay, OH|     NextSong|              Canada|1538429971000|
# |1000280|   true|                null|Logged In|    Frank|     M|  Warren|     null| free|Findlay, OH|    Thumbs Up|                null|1538429972000|
# |1000280|   true|    Inspiral Carpets|Logged In|    Frank|     M|  Warren|194.14159| free|Findlay, OH|     NextSong|This Is How It Feels|1538430207000|
# |1000280|   true|    Five Iron Frenzy|Logged In|    Frank|     M|  Warren|236.09424| free|Findlay, OH|     NextSong|              Canada|1538430401000|
# |1000280|   true|                null|Logged In|    Frank|     M|  Warren|     null| free|Findlay, OH|         Help|                null|1538430406000|
# |1000280|   true|                null|Logged In|    Frank|     M|  Warren|     null| free|Findlay, OH|     Settings|                null|1538430413000|
# |1000280|   true|                null|Logged In|    Frank|     M|  Warren|     null| free|Findlay, OH|Save Settings|                null|1538430414000|
# |1000280|   true|                null|Logged In|    Frank|     M|  Warren|     null| free|Findlay, OH|         Home|                null|1538430574000|
# |1000280|   true|              Beirut|Logged In|    Frank|     M|  Warren|206.57587| free|Findlay, OH|     NextSong|       The Concubine|1538430637000|
# |1000280|   true|Frankie Goes To H...|Logged In|    Frank|     M|  Warren|237.97506| free|Findlay, OH|     NextSong|               Relax|1538430843000|
# |1000280|   true|                null|Logged In|    Frank|     M|  Warren|     null| free|Findlay, OH|  Roll Advert|                null|1538430911000|
# +-------+-------+--------------------+---------+---------+------+--------+---------+-----+-----------+-------------+--------------------+-------------+
# only showing top 20 rows

# %%
df_label.persist(StorageLevel.MEMORY_AND_DISK)
# Out:
# VBox()
# DataFrame[userId: string, Churned: string, artist: string, auth: string, firstName: string, gender: string, lastName: string, length: double, level: string, location: string, page: string, song: string, ts: bigint]

# %%
df_label.select(["userId","Churned"]).distinct().groupBy("Churned").count().collect()
# Out:
# VBox()
# [Row(Churned=u'false', count=17275), Row(Churned=u'true', count=5003)]

# %% [markdown]
# #### Check for nulls

# %%
df_label.select([count(when(isnull(c), c)).alias(c) for c in df_label.columns]).show()
# Out:
# VBox()
# +------+-------+-------+----+---------+------+--------+-------+-----+--------+----+-------+---+
# |userId|Churned| artist|auth|firstName|gender|lastName| length|level|location|page|   song| ts|
# +------+-------+-------+----+---------+------+--------+-------+-----+--------+----+-------+---+
# |     0|      0|5408927|   0|   778479|778479|  778479|5408927|    0|  778479|   0|5408927|  0|
# +------+-------+-------+----+---------+------+--------+-------+-----+--------+----+-------+---+

# %% [markdown]
# ### Add Features

# %%
thumbsUp = df_label.where(df_label.page=='Thumbs Up').groupby("userId").agg(count(col('page')).alias('ThumbsUp')).orderBy('userId')
# Out:
# VBox()

# %%
thumbsDown = df_label.where(df_label.page=='Thumbs Down').groupby("userId").agg(count(col('page')).alias('ThumbsDown')).orderBy('userId')
# Out:
# VBox()

# %%
allThumbs = thumbsUp.join(thumbsDown,'userId')
# Out:
# VBox()

# %%
songsPlayed = df_label.where(col('song')!='null').groupby("userId").agg(count(col('song')).alias('SongsPlayed')).orderBy('userId')
# Out:
# VBox()

# %%
df_features = df_churn.join(songsPlayed,'userId')
df_features = df_features.join(allThumbs,'userId')
# Out:
# VBox()

# %%
days = df_label.groupby('userId').agg(((max(col('ts')) - min(col('ts')))/86400000).alias("Days"))
df_features = df_features.join(days, "userId")
# Out:
# VBox()

# %%
df_features.select([count(when(isnull(c), c)).alias(c) for c in ["userId", "SongsPlayed", "ThumbsUp", "ThumbsDown", "Days"]]).show()
# Out:
# VBox()
# +------+-----------+--------+----------+----+
# |userId|SongsPlayed|ThumbsUp|ThumbsDown|Days|
# +------+-----------+--------+----------+----+
# |     0|          0|       0|         0|   0|
# +------+-----------+--------+----------+----+

# %%
upPerSong = udf(lambda numUp, songs: float(numUp)/float(songs), FloatType())
downPerSong = udf(lambda numDown, songs: float(numDown)/float(songs), FloatType())
songsPerHour = udf(lambda numSongs, numDays: float(numSongs)/float((numDays*24)), FloatType())
# Out:
# VBox()

# %%
columns = ['id', 'num1', 'num2']
vals = [
     (1, 8, 4),
     (2, 7, 5)
]
smalldf = spark.createDataFrame(vals, columns)
# Out:
# VBox()

# %%
smalldf.drop("UpPerSong")
smalldf = smalldf.withColumn("UpPerSong", upPerSong(smalldf.num1, smalldf.num2))
smalldf.show()
# Out:
# VBox()
# +---+----+----+---------+
# | id|num1|num2|UpPerSong|
# +---+----+----+---------+
# |  1|   8|   4|      2.0|
# |  2|   7|   5|      1.4|
# +---+----+----+---------+

# %%
df_features = df_features.withColumn("UpPerSong", upPerSong(df_features.ThumbsUp, df_features.SongsPlayed))
# Out:
# VBox()

# %%
df_features.show()
# Out:
# VBox()
# +-------+-------+-----------+--------+----------+------------------+-----------+
# | userId|Churned|SongsPlayed|ThumbsUp|ThumbsDown|              Days|  UpPerSong|
# +-------+-------+-----------+--------+----------+------------------+-----------+
# |1000280|   true|       1022|      53|        33|43.075775462962966|  0.0518591|
# |1002185|  false|       1778|      92|        14| 57.97252314814815|0.051743533|
# |1017805|  false|        250|       7|         4|24.672766203703702|      0.028|
# |1030587|  false|       1472|      66|        16| 49.20280092592593|0.044836957|
# |1033297|  false|        236|      10|         3| 33.12201388888889|0.042372882|
# |1057724|  false|       3847|     200|        29|         58.329375| 0.05198856|
# |1059049|  false|        559|      29|         6| 37.39221064814815|0.051878355|
# |1069552|  false|        455|      26|         6|55.920520833333335|0.057142857|
# |1071308|   true|       1409|      74|        12| 38.46319444444445| 0.05251952|
# |1076191|   true|         47|       4|         1| 7.876053240740741| 0.08510638|
# |1083324|  false|       1484|      75|        11| 59.30815972222222|0.050539084|
# |1102913|  false|        753|      38|         9| 55.98508101851852| 0.05046481|
# |1114507|  false|        848|      47|        11| 59.70662037037037| 0.05542453|
# |1133196|  false|        731|      70|         6|51.180844907407405|0.095759235|
# |1142513|  false|        480|      22|         4|56.927569444444444|0.045833334|
# |1151194|  false|       1302|      60|        14| 56.70784722222222| 0.04608295|
# |1156065|   true|        231|      10|         4|16.535960648148148|0.043290045|
# |1178731|  false|       2663|     147|        27| 60.76435185185185|  0.0552009|
# |1180406|  false|        552|      23|         6|56.148148148148145|0.041666668|
# |1190352|  false|       2216|     113|        28| 57.10296296296296| 0.05099278|
# +-------+-------+-----------+--------+----------+------------------+-----------+
# only showing top 20 rows

# %%
df_features = df_features.withColumn("DownPerSong", downPerSong(df_features.ThumbsDown, df_features.SongsPlayed))
# Out:
# VBox()

# %%
df_features = df_features.withColumn("SongsPerHour", songsPerHour(df_features.SongsPlayed, df_features.Days))
# Out:
# VBox()

# %%
df_features.select("SongsPerHour", "Churned").groupby("Churned").agg(avg(col('SongsPerHour'))).show()
# Out:
# VBox()
# +-------+-----------------+
# |Churned|avg(SongsPerHour)|
# +-------+-----------------+
# |  false|1.076505910115338|
# |   true|2.284715742469593|
# +-------+-----------------+

# %%
df_features.select([count(when(isnull(c), c)).alias(c) for c in ["SongsPlayed", "UpPerSong", "DownPerSong", "Days", "SongsPerHour"]]).show()
# Out:
# VBox()
# +-----------+---------+-----------+----+------------+
# |SongsPlayed|UpPerSong|DownPerSong|Days|SongsPerHour|
# +-----------+---------+-----------+----+------------+
# |          0|        0|          0|   0|           0|
# +-----------+---------+-----------+----+------------+

# %% [markdown]
# ### Vectorize and scale features

# %%
assembler = VectorAssembler(inputCols=["SongsPlayed", "UpPerSong", "DownPerSong", "Days", "SongsPerHour"], outputCol="FeatureVector")
df_features = assembler.transform(df_features)
# Out:
# VBox()

# %%
scaler = StandardScaler(inputCol="FeatureVector", outputCol="ScaledFeatures", withStd=True)
scalerModel = scaler.fit(df_features)
df_features = scalerModel.transform(df_features)
# Out:
# VBox()

# %%
df_features.show()
# Out:
# VBox()
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+
# | userId|Churned|SongsPlayed|ThumbsUp|ThumbsDown|              Days|  UpPerSong| DownPerSong|SongsPerHour|       FeatureVector|      ScaledFeatures|
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+
# |1000280|   true|       1022|      53|        33|43.075775462962966|  0.0518591| 0.032289628|    0.988568|[1022.0,0.0518590...|[0.91242495298452...|
# |1002185|  false|       1778|      92|        14| 57.97252314814815|0.051743533| 0.007874016|   1.2779043|[1778.0,0.0517435...|[1.58736943875390...|
# |1017805|  false|        250|       7|         4|24.672766203703702|      0.028|       0.016|   0.4221929|[250.0,0.02800000...|[0.22319592783378...|
# |1030587|  false|       1472|      66|        16| 49.20280092592593|0.044836957| 0.010869565|   1.2465415|[1472.0,0.0448369...|[1.31417762308534...|
# |1033297|  false|        236|      10|         3| 33.12201388888889|0.042372882| 0.012711864|  0.29688212|[236.0,0.04237288...|[0.21069695587509...|
# |1057724|  false|       3847|     200|        29|         58.329375| 0.05198856|0.0075383415|   2.7480435|[3847.0,0.0519885...|[3.43453893750634...|
# |1059049|  false|        559|      29|         6| 37.39221064814815|0.051878355| 0.010733453|  0.62290156|[559.0,0.05187835...|[0.49906609463635...|
# |1069552|  false|        455|      26|         6|55.920520833333335|0.057142857| 0.013186813|  0.33902285|[455.0,0.05714285...|[0.40621658865749...|
# |1071308|   true|       1409|      74|        12| 38.46319444444445| 0.05251952| 0.008516679|    1.526351|[1409.0,0.0525195...|[1.25793224927123...|
# |1076191|   true|         47|       4|         1| 7.876053240740741| 0.08510638| 0.021276595|    0.248644|[47.0,0.085106380...|[0.04196083443275...|
# |1083324|  false|       1484|      75|        11| 59.30815972222222|0.050539084|0.0074123987|   1.0425771|[1484.0,0.0505390...|[1.32489102762137...|
# |1102913|  false|        753|      38|         9| 55.98508101851852| 0.05046481| 0.011952192|   0.5604172|[753.0,0.05046480...|[0.67226613463537...|
# |1114507|  false|        848|      47|        11| 59.70662037037037| 0.05542453| 0.012971698|   0.5917825|[848.0,0.05542453...|[0.75708058721221...|
# |1133196|  false|        731|      70|         6|51.180844907407405|0.095759235| 0.008207934|  0.59511197|[731.0,0.09575923...|[0.65262489298599...|
# |1142513|  false|        480|      22|         4|56.927569444444444|0.045833334| 0.008333334|  0.35132363|[480.0,0.04583333...|[0.42853618144087...|
# |1151194|  false|       1302|      60|        14| 56.70784722222222| 0.04608295| 0.010752688|   0.9566577|[1302.0,0.0460829...|[1.16240439215837...|
# |1156065|   true|        231|      10|         4|16.535960648148148|0.043290045| 0.017316017|  0.58206475|[231.0,0.04329004...|[0.20623303731842...|
# |1178731|  false|       2663|     147|        27| 60.76435185185185|  0.0552009| 0.010138941|   1.8260432|[2663.0,0.0552009...|[2.37748302328551...|
# |1180406|  false|        552|      23|         6|56.148148148148145|0.041666668| 0.010869565|   0.4096306|[552.0,0.04166666...|[0.49281660865700...|
# |1190352|  false|       2216|     113|        28| 57.10296296296296| 0.05099278| 0.012635379|   1.6169622|[2216.0,0.0509927...|[1.97840870431870...|
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+
# only showing top 20 rows

# %%
convertToInt = udf(lambda x: 1 if x=="true" else 0, IntegerType())
# Out:
# VBox()

# %%
df_features = df_features.withColumn('label', convertToInt(df_features.Churned))
# Out:
# VBox()

# %% [markdown]
# ### Split data into training, test and validation

# %%
df_features.show()
# Out:
# VBox()
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+-----+
# | userId|Churned|SongsPlayed|ThumbsUp|ThumbsDown|              Days|  UpPerSong| DownPerSong|SongsPerHour|       FeatureVector|      ScaledFeatures|label|
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+-----+
# |1000280|   true|       1022|      53|        33|43.075775462962966|  0.0518591| 0.032289628|    0.988568|[1022.0,0.0518590...|[0.91242495298452...|    1|
# |1002185|  false|       1778|      92|        14| 57.97252314814815|0.051743533| 0.007874016|   1.2779043|[1778.0,0.0517435...|[1.58736943875390...|    0|
# |1017805|  false|        250|       7|         4|24.672766203703702|      0.028|       0.016|   0.4221929|[250.0,0.02800000...|[0.22319592783378...|    0|
# |1030587|  false|       1472|      66|        16| 49.20280092592593|0.044836957| 0.010869565|   1.2465415|[1472.0,0.0448369...|[1.31417762308534...|    0|
# |1033297|  false|        236|      10|         3| 33.12201388888889|0.042372882| 0.012711864|  0.29688212|[236.0,0.04237288...|[0.21069695587509...|    0|
# |1057724|  false|       3847|     200|        29|         58.329375| 0.05198856|0.0075383415|   2.7480435|[3847.0,0.0519885...|[3.43453893750634...|    0|
# |1059049|  false|        559|      29|         6| 37.39221064814815|0.051878355| 0.010733453|  0.62290156|[559.0,0.05187835...|[0.49906609463635...|    0|
# |1069552|  false|        455|      26|         6|55.920520833333335|0.057142857| 0.013186813|  0.33902285|[455.0,0.05714285...|[0.40621658865749...|    0|
# |1071308|   true|       1409|      74|        12| 38.46319444444445| 0.05251952| 0.008516679|    1.526351|[1409.0,0.0525195...|[1.25793224927123...|    1|
# |1076191|   true|         47|       4|         1| 7.876053240740741| 0.08510638| 0.021276595|    0.248644|[47.0,0.085106380...|[0.04196083443275...|    1|
# |1083324|  false|       1484|      75|        11| 59.30815972222222|0.050539084|0.0074123987|   1.0425771|[1484.0,0.0505390...|[1.32489102762137...|    0|
# |1102913|  false|        753|      38|         9| 55.98508101851852| 0.05046481| 0.011952192|   0.5604172|[753.0,0.05046480...|[0.67226613463537...|    0|
# |1114507|  false|        848|      47|        11| 59.70662037037037| 0.05542453| 0.012971698|   0.5917825|[848.0,0.05542453...|[0.75708058721221...|    0|
# |1133196|  false|        731|      70|         6|51.180844907407405|0.095759235| 0.008207934|  0.59511197|[731.0,0.09575923...|[0.65262489298599...|    0|
# |1142513|  false|        480|      22|         4|56.927569444444444|0.045833334| 0.008333334|  0.35132363|[480.0,0.04583333...|[0.42853618144087...|    0|
# |1151194|  false|       1302|      60|        14| 56.70784722222222| 0.04608295| 0.010752688|   0.9566577|[1302.0,0.0460829...|[1.16240439215837...|    0|
# |1156065|   true|        231|      10|         4|16.535960648148148|0.043290045| 0.017316017|  0.58206475|[231.0,0.04329004...|[0.20623303731842...|    1|
# |1178731|  false|       2663|     147|        27| 60.76435185185185|  0.0552009| 0.010138941|   1.8260432|[2663.0,0.0552009...|[2.37748302328551...|    0|
# |1180406|  false|        552|      23|         6|56.148148148148145|0.041666668| 0.010869565|   0.4096306|[552.0,0.04166666...|[0.49281660865700...|    0|
# |1190352|  false|       2216|     113|        28| 57.10296296296296| 0.05099278| 0.012635379|   1.6169622|[2216.0,0.0509927...|[1.97840870431870...|    0|
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+-----+
# only showing top 20 rows

# %%
train, test = df_features.randomSplit([0.8, 0.2], seed=42)
train, validation = train.randomSplit([0.8, 0.2], seed=42)
# Out:
# VBox()

# %% [markdown]
# ### Train the model using LogisitcRegression and default params

# %%
lr = LogisticRegression(featuresCol = 'FeatureVector', labelCol = 'label', maxIter=10)
lrModel = lr.fit(train)
# Out:
# VBox()

# %%
trainingSummary = lrModel.summary
# Out:
# VBox()

# %% [markdown]
# #### Code developed from Apache Spark documention examples [Spark](https://spark.apache.org/docs/2.1.1/ml-classification-regression.html)

# %%
objectiveHistory = trainingSummary.objectiveHistory
print("objectiveHistory:")
for objective in objectiveHistory:
    print(objective)

# Obtain the receiver-operating characteristic as a dataframe and areaUnderROC.
trainingSummary.roc.show()
print("areaUnderROC: " + str(trainingSummary.areaUnderROC))
# Out:
# VBox()
# objectiveHistory:
# 0.539919604573
# 0.509239460563
# 0.475498528905
# 0.442098634351
# 0.437150329445
# 0.424084673606
# 0.402606328971
# 0.385793271091
# 0.373180789382
# 0.363566860268
# 0.362864432603
# +--------------------+-------------------+
# |                 FPR|                TPR|
# +--------------------+-------------------+
# |                 0.0|                0.0|
# |0.001330195436406426|0.01707650273224044|
# |0.002353422695180...| 0.0351775956284153|
# |0.003581295405709...|0.05293715846994536|
# |0.004706845390361199|0.07137978142076502|
# | 0.00624168627852246|0.08709016393442623|
# |0.007060268085541799|0.10621584699453553|
# |0.009106722603090147|0.12158469945355191|
# | 0.01012994986186432| 0.1403688524590164|
# |0.011767113475902998| 0.1567622950819672|
# |0.012994986186432007|0.17349726775956284|
# |0.013608922541696511|0.19330601092896174|
# |0.015860022510999692|0.20799180327868852|
# | 0.01719021794740612|0.22472677595628415|
# |0.019032027013199632| 0.2421448087431694|
# | 0.02056686790136089|  0.258879781420765|
# | 0.02189706333776732|0.27527322404371585|
# |0.023534226951805997| 0.2930327868852459|
# | 0.02537603601759951| 0.3084016393442623|
# |0.026706231454005934|0.32479508196721313|
# +--------------------+-------------------+
# only showing top 20 rows
#
# areaUnderROC: 0.871222865607

# %%
fMeasure = trainingSummary.fMeasureByThreshold
maxFMeasure = fMeasure.groupBy().max('F-Measure').select('max(F-Measure)').head()
bestThreshold = fMeasure.where(fMeasure['F-Measure'] == maxFMeasure['max(F-Measure)']) \
    .select('threshold').head()['threshold']
# Out:
# VBox()

# %%
fMeasure.show()
# Out:
# VBox()
# +------------------+-------------------+
# |         threshold|          F-Measure|
# +------------------+-------------------+
# |0.9710608906938891|0.03343363423604146|
# |0.9115624899646096|0.06745252128356254|
# |0.8940708087293442|0.09942270686337396|
# |0.8822248997747707|0.13132265158655357|
# |0.8706226669247632|0.15721331689272502|
# |0.8606218801695937|0.18802902055622733|
# |0.8503564372998402| 0.2110880521790691|
# |0.8405966828998392|0.23909249563699825|
# |0.8319074916080038| 0.2621359223300971|
# |0.8222063007289495| 0.2851529609879315|
# |0.8133804957436582| 0.3121036669423766|
# |0.8049741760959546|0.32990249187432286|
# |0.7963324846658016| 0.3505594033031433|
# |0.7879623520054181| 0.3709128956317029|
# |0.7791499519799358|0.39001800874710574|
# |0.7685809722581675| 0.4083080040526849|
# |0.7584430249145967| 0.4272908366533864|
# |0.7477319327542814| 0.4427555773473891|
# | 0.737471651564837|0.45942028985507244|
# |0.7266642335110222| 0.4709800190294957|
# +------------------+-------------------+
# only showing top 20 rows

# %%
print(bestThreshold)
print(maxFMeasure)
# Out:
# VBox()
# 0.302889278373
# Row(max(F-Measure)=0.6617299511580275)

# %%
pr = trainingSummary.pr
# Out:
# VBox()

# %%
pr.show()
# Out:
# VBox()
# +-------------------+------------------+
# |             recall|         precision|
# +-------------------+------------------+
# |                0.0|0.7936507936507936|
# |0.01707650273224044|0.7936507936507936|
# | 0.0351775956284153|0.8174603174603174|
# |0.05293715846994536|0.8157894736842105|
# |0.07137978142076502|0.8196078431372549|
# |0.08709016393442623|0.8069620253164557|
# |0.10621584699453553|0.8184210526315789|
# |0.12158469945355191|               0.8|
# | 0.1403688524590164|0.8058823529411765|
# | 0.1567622950819672|0.7996515679442509|
# |0.17349726775956284|               0.8|
# |0.19330601092896174|0.8097281831187411|
# |0.20799180327868852|0.7971204188481675|
# |0.22472677595628415|0.7966101694915254|
# | 0.2421448087431694|0.7921787709497207|
# |  0.258879781420765|0.7904066736183525|
# |0.27527322404371585|0.7901960784313725|
# | 0.2930327868852459|0.7886029411764706|
# | 0.3084016393442623|0.7845351867940921|
# |0.32479508196721313|0.7846534653465347|
# +-------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### Make predictions on validation set

# %%
predictions = lrModel.transform(validation)
# Out:
# VBox()

# %%
predictions.show()
# Out:
# VBox()
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+-----+--------------------+--------------------+----------+
# | userId|Churned|SongsPlayed|ThumbsUp|ThumbsDown|              Days|  UpPerSong| DownPerSong|SongsPerHour|       FeatureVector|      ScaledFeatures|label|       rawPrediction|         probability|prediction|
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+-----+--------------------+--------------------+----------+
# |1002185|  false|       1778|      92|        14| 57.97252314814815|0.051743533| 0.007874016|   1.2779043|[1778.0,0.0517435...|[1.58736943875390...|    0|[2.76861114742403...|[0.94095587201545...|       0.0|
# |1017805|  false|        250|       7|         4|24.672766203703702|      0.028|       0.016|   0.4221929|[250.0,0.02800000...|[0.22319592783378...|    0|[-0.3961962869845...|[0.40222656489231...|       1.0|
# |1030587|  false|       1472|      66|        16| 49.20280092592593|0.044836957| 0.010869565|   1.2465415|[1472.0,0.0448369...|[1.31417762308534...|    0|[1.86786304875018...|[0.86621082071443...|       0.0|
# |1133196|  false|        731|      70|         6|51.180844907407405|0.095759235| 0.008207934|  0.59511197|[731.0,0.09575923...|[0.65262489298599...|    0|[3.59664513934490...|[0.97331601236202...|       0.0|
# |1156065|   true|        231|      10|         4|16.535960648148148|0.043290045| 0.017316017|  0.58206475|[231.0,0.04329004...|[0.20623303731842...|    1|[-0.9625918164701...|[0.27635957024458...|       1.0|
# |1384823|  false|       1023|      56|         9|45.425694444444446|0.054740958| 0.008797654|   0.9383456|[1023.0,0.0547409...|[0.91331773669586...|    0|[1.97486297038968...|[0.87813248565364...|       0.0|
# |1531916|  false|         41|       3|         2|29.702291666666667| 0.07317073| 0.048780486| 0.057515204|[41.0,0.073170728...|[0.03660413216474...|    0|[0.76122132841220...|[0.68161883865436...|       0.0|
# |1532306|  false|        132|       5|         2|44.351412037037036| 0.03787879| 0.015151516|  0.12400958|[132.0,0.03787878...|[0.11784744989624...|    0|[2.01338588570160...|[0.88219536175212...|       0.0|
# |1567400|   true|        128|       3|         1| 23.26763888888889|  0.0234375|   0.0078125|  0.22921678|[128.0,0.0234375,...|[0.11427631505089...|    1|[-0.4784680964949...|[0.38261392712635...|       1.0|
# |1619792|  false|       1378|      68|        11| 56.36950231481482| 0.04934688| 0.007982584|   1.0185767|[1378.0,0.0493468...|[1.23025595421984...|    0|[2.81488030518221...|[0.94347465100657...|       0.0|
# |1656082|  false|        115|       4|         2| 47.45693287037037|0.034782607| 0.017391304|  0.10096874|[115.0,0.03478260...|[0.10267012680354...|    0|[2.27596840943583...|[0.90686710020146...|       0.0|
# |1782257|  false|        313|      22|         2| 23.40111111111111| 0.07028754|0.0063897762|  0.55730975|[313.0,0.07028754...|[0.27944130164790...|    0|[0.38653033484924...|[0.59544716976175...|       0.0|
# |1803077|  false|        468|      22|         6| 44.37436342592593|0.047008548| 0.012820513|  0.43944293|[468.0,0.04700854...|[0.41782277690485...|    0|[2.01219334077541...|[0.88207136798702...|       0.0|
# |1828442|  false|        232|      10|         8| 57.64684027777778| 0.04310345|  0.03448276|  0.16768771|[232.0,0.04310344...|[0.20712582102975...|    0|[3.27405805776005...|[0.96352804753005...|       0.0|
# |1010669|  false|       2606|     139|        23| 60.01258101851852| 0.05333845| 0.008825786|   1.8093429|[2606.0,0.0533384...|[2.32659435173941...|    0|[2.45114525989967...|[0.92064516112924...|       0.0|
# |1037661|   true|       1063|      44|        14| 45.31506944444445|0.041392285| 0.013170273|  0.97741586|[1063.0,0.0413922...|[0.94902908514926...|    1|[1.62193243577828...|[0.83506146392652...|       0.0|
# |1115503|  false|        435|      22|         6| 44.09646990740741|0.050574712| 0.013793103|  0.41103062|[435.0,0.05057471...|[0.38836091443079...|    0|[2.06171894762136...|[0.88712640813134...|       0.0|
# |1182408|  false|       2560|     115|        33|60.007395833333334|0.044921875| 0.012890625|   1.7775587|[2560.0,0.0449218...|[2.28552630101799...|    0|[2.26666879651700...|[0.90607868523136...|       0.0|
# |1259044|  false|        432|      24|        10| 51.03771990740741|0.055555556| 0.023148147|  0.35268033|[432.0,0.05555555...|[0.38568256329678...|    0|[2.80328107166235...|[0.94285286971921...|       0.0|
# |1297189|  false|        364|      28|        14| 50.69990740740741| 0.07692308|  0.03846154|  0.29914585|[364.0,0.07692307...|[0.32497327092599...|    0|[3.04985477068512...|[0.95477625613863...|       0.0|
# +-------+-------+-----------+--------+----------+------------------+-----------+------------+------------+--------------------+--------------------+-----+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
print(predictions.filter(predictions.label == predictions.prediction).count())
print(predictions.count())
# Out:
# VBox()
# 2757
# 3186

# %%
print(2757.0/3186.0)*100
# Out:
# VBox()
# 86.5348399247

# %%
evaluator = BinaryClassificationEvaluator()
print('Area Under ROC', evaluator.evaluate(predictions))
# Out:
# VBox()
# ('Test Area Under ROC', 0.8617849953633544)

# %% [markdown]
# ### Tune hyper-parameters

# %%
lr.setThreshold(bestThreshold)
# Out:
# VBox()
# LogisticRegression_903c0d8e676c

# %%
paramGrid = ParamGridBuilder().addGrid(lr.regParam, [0.1, 0.01]).build()
# Out:
# VBox()

# %%
crossval = CrossValidator(estimator=lr,
                          estimatorParamMaps=paramGrid,
                          evaluator=BinaryClassificationEvaluator(),
                          numFolds=3)
# Out:
# VBox()

# %%
cvModel = crossval.fit(train)
prediction = cvModel.transform(validation)
# Out:
# VBox()

# %%
print(prediction.filter(prediction.label == prediction.prediction).count())
print(prediction.count())
# Out:
# VBox()
# 2618
# 3186

# %%
print(2618.0/3186.0 * 100)
# Out:
# VBox()
# 82.172002511

# %%
print('Area Under ROC', evaluator.evaluate(prediction))
# Out:
# VBox()
# ('Area Under ROC', 0.861853414154208)

# %% [markdown]
# ### Apply the model to the test data

# %%
predictions_test = cvModel.transform(test)
# Out:
# VBox()

# %%
print(predictions_test.filter(predictions_test.label == predictions_test.prediction).count())
print(predictions_test.count())
# Out:
# VBox()
# 3366
# 4005

# %%
print(3366.0/4005.0)*100
# Out:
# VBox()
# 84.0449438202

# %%
print('Area Under ROC', evaluator.evaluate(predictions_test))
# Out:
# VBox()
# ('Area Under ROC', 0.8762050562457436)

# %% [markdown]
# #### The default model seemed to work best. Try it on the test data:

# %%
predictions = lrModel.transform(test)
# Out:
# VBox()

# %%
print(predictions.filter(predictions.label == predictions.prediction).count())
print(predictions.count())
# Out:
# VBox()
# Exception in thread cell_monitor-137:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/awseditorssparkmonitoringwidget-1.0-py3.6.egg/awseditorssparkmonitoringwidget/cellmonitor.py", line 178, in cell_monitor
#     job_binned_stages[job_id][stage_id] = all_stages[stage_id]
# KeyError: 4298
# 3377
# 4005

# %%
print(3377.0/4005.0)*100
# Out:
# VBox()
# 84.3196004994

# %%
print('Area Under ROC', evaluator.evaluate(predictions))
# Out:
# VBox()
# ('Area Under ROC', 0.8765631972006295)

# %% [markdown]
# #### Conclusion, the default model is slightly more accurate than the tuned one.

# %%
lrModel.coefficients
# Out:
# VBox()
# DenseVector([0.0008, -19.7478, 11.9394, -0.1098, -0.1607])

# %% [markdown]
# Based on the coefficients, the features that contribute the most are:
#
# 1. Average number of thumbsdown per song played
# 2. Number of songs played
